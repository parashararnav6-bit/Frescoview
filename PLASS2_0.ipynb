# %% [markdown]
# <a href="https://colab.research.google.com/github/parashararnav6-bit/Frescoview/blob/main/PLASS2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=7
print(n*n)
# Out:
# 49
